# %%
mlflow --version
# Out:
# mlflow, version 2.13.0

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error
import mlflow
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import os
import pickle
import click

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid
import numpy as np
from mlflow.entities import ViewType
from mlflow.tracking import MlflowClient

# %%
def dump_pickle(obj, filename: str):
    with open(filename, "wb") as f_out:
        return pickle.dump(obj, f_out)

# %%
def read_dataframe(filename: str):
    df = pd.read_parquet(filename)

    df['duration'] = df['lpep_dropoff_datetime'] - df['lpep_pickup_datetime']
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)

    return df

# %%
def preprocess(df: pd.DataFrame, dv: DictVectorizer, fit_dv: bool = False):
    df['PU_DO'] = df['PULocationID'] + '_' + df['DOLocationID']
    categorical = ['PU_DO']
    numerical = ['trip_distance']
    dicts = df[categorical + numerical].to_dict(orient='records')
    if fit_dv:
        X = dv.fit_transform(dicts)
    else:
        X = dv.transform(dicts)
    return X, dv

# %%
def run_data_prep(raw_data_path: str, dest_path: str, dataset: str = "green"):
    # Load parquet files
    df_train = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-01.parquet")
    )
    df_val = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-02.parquet")
    )
    df_test = read_dataframe(
        os.path.join(raw_data_path, f"{dataset}_tripdata_2023-03.parquet")
    )

    # Extract the target
    target = 'duration'
    y_train = df_train[target].values
    y_val = df_val[target].values
    y_test = df_test[target].values

    # Fit the DictVectorizer and preprocess data
    dv = DictVectorizer()
    X_train, dv = preprocess(df_train, dv, fit_dv=True)
    X_val, _ = preprocess(df_val, dv, fit_dv=False)
    X_test, _ = preprocess(df_test, dv, fit_dv=False)

    # Create dest_path folder unless it already exists
    os.makedirs(dest_path, exist_ok=True)

    # Save DictVectorizer and datasets
    dump_pickle(dv, os.path.join(dest_path, "dv.pkl"))
    dump_pickle((X_train, y_train), os.path.join(dest_path, "train.pkl"))
    dump_pickle((X_val, y_val), os.path.join(dest_path, "val.pkl"))
    dump_pickle((X_test, y_test), os.path.join(dest_path, "test.pkl"))

# %%
run_data_prep('','/data2')

# %%
def load_pickle(filename: str):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)

# %%
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment2023")
# Out:
# 2024/05/30 02:07:37 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment2023' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/homework/mlruns/1', creation_time=1717024057620, experiment_id='1', last_update_time=1717024057620, lifecycle_stage='active', name='nyc-taxi-experiment2023', tags={}>

# %%
def run_train(data_path: str):

   # Define the hyperparameter grid
    param_grid = {
        "max_depth": [5, 10],
        "n_estimators": [50, 100],
        "min_samples_split": [2, 5, 10],
        "random_state": [0]
    }

    # Create a parameter grid
    grid = ParameterGrid(param_grid)
    
    best_rmse = float("inf")
    best_params = None
    
    for params in grid:
        with mlflow.start_run():
            mlflow.set_tag("model", "RandomForestRegressor")
            mlflow.log_params(params)

            X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
            X_val, y_val = load_pickle(os.path.join(data_path, "val.pkl"))

            rf = RandomForestRegressor(**params)
            rf.fit(X_train, y_train)
            y_pred = rf.predict(X_val)

            rmse = mean_squared_error(y_val, y_pred, squared=False)
            mlflow.log_metric("rmse", rmse)

            if rmse < best_rmse:
                best_rmse = rmse
                best_params = params

            # Optionally log the model artifact
            model_path = "mlruns/models/random.bin"
            with open(model_path, "wb") as f:
                pickle.dump(rf, f)
            mlflow.log_artifact(local_path=model_path, artifact_path="models_pickle")

    print(f"Best RMSE: {best_rmse} with parameters: {best_params}")
    return best_rmse, best_params

# %%
run_train('/data2')
# Out:
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Best RMSE: 5.429788415830813 with parameters: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 50, 'random_state': 0}
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (5.429788415830813,
#  {'max_depth': 10,
#   'min_samples_split': 10,
#   'n_estimators': 50,
#   'random_state': 0})

# %%
def run_optimization(data_path: str, num_trials: int):

    X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
    X_val, y_val = load_pickle(os.path.join(data_path, "val.pkl"))

    def objective(params):

      with mlflow.start_run():
        mlflow.set_tag("model", "RandomForest")
        mlflow.log_params(params)
        rf = RandomForestRegressor(**params)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

        return {'loss': rmse, 'status': STATUS_OK}

    search_space = {
        'max_depth': scope.int(hp.quniform('max_depth', 1, 20, 1)),
        'n_estimators': scope.int(hp.quniform('n_estimators', 10, 50, 1)),
        'min_samples_split': scope.int(hp.quniform('min_samples_split', 2, 10, 1)),
        'min_samples_leaf': scope.int(hp.quniform('min_samples_leaf', 1, 4, 1)),
        'random_state': 42
    }

    rstate = np.random.default_rng(42)  # for reproducible results
    fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=num_trials,
        trials=Trials(),
        rstate=rstate
    )

# %%
run_optimization('/data2',2)
# Out:
#   0%|          | 0/2 [00:00<?, ?trial/s, best loss=?]
# 2024/05/30 22:24:27 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
#  50%|█████     | 1/2 [00:33<00:33, 33.34s/trial, best loss: 5.370086069268862]
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# 2024/05/30 22:25:00 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 100%|██████████| 2/2 [00:42<00:00, 21.03s/trial, best loss: 5.370086069268862]
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Define constants
HPO_EXPERIMENT_NAME = "random-forest-hyperopt"
EXPERIMENT_NAME = "random-forest-best-models"
RF_PARAMS = ['max_depth', 'n_estimators', 'min_samples_split', 'min_samples_leaf', 'random_state']
MODEL_NAME = "random-forest"

# Set tracking URI and experiment
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment(EXPERIMENT_NAME)
mlflow.set_experiment(HPO_EXPERIMENT_NAME)
mlflow.sklearn.autolog()
# Out:
# 2024/05/30 22:11:08 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.

# %%
# Set tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# Ensure the experiments exist
client = MlflowClient()

def get_or_create_experiment(name):
    experiment = client.get_experiment_by_name(name)
    if experiment is None:
        print(f"Experiment '{name}' not found. Creating it.")
        experiment_id = mlflow.create_experiment(name)
        experiment = client.get_experiment(experiment_id)
    return experiment

hpo_experiment = get_or_create_experiment(HPO_EXPERIMENT_NAME)
main_experiment = get_or_create_experiment(EXPERIMENT_NAME)

# Enable autologging
mlflow.sklearn.autolog()
# Out:
# 2024/05/30 22:11:28 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.

# %%
def load_pickle(filename):
    with open(filename, "rb") as f_in:
        return pickle.load(f_in)

# %%
def train_and_log_model(data_path: str, params: dict):
    with mlflow.start_run():
        mlflow.set_tag("model", "RandomForestRegressor")
        mlflow.log_params(params)

        X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
        X_val, y_val = load_pickle(os.path.join(data_path, "val.pkl"))
        X_test, y_test = load_pickle(os.path.join(data_path, "test.pkl"))

        rf = RandomForestRegressor(**params)
        rf.fit(X_train, y_train)
        y_pred_val = rf.predict(X_val)
        y_pred_test = rf.predict(X_test)

        val_rmse = mean_squared_error(y_val, y_pred_val, squared=False)
        test_rmse = mean_squared_error(y_test, y_pred_test, squared=False)

        mlflow.log_metric("val_rmse", val_rmse)
        mlflow.log_metric("test_rmse", test_rmse)

        # Save model artifact
        model_path = "random_forest_model.pkl"
        with open(model_path, "wb") as f:
            pickle.dump(rf, f)
        mlflow.log_artifact(local_path=model_path, artifact_path="models_pickle")

# %%
train_and_log_model(data_path=data_path, params=run.data.params)

# %%
def run_register_model(data_path: str, top_n: int):
    client = MlflowClient()

    # Retrieve the top_n model runs from HPO experiment
    hpo_experiment = client.get_experiment_by_name(HPO_EXPERIMENT_NAME)
    if hpo_experiment is None:
        raise ValueError(f"Experiment '{HPO_EXPERIMENT_NAME}' not found.")
    
    runs = client.search_runs(
        experiment_ids=hpo_experiment.experiment_id,
        run_view_type=ViewType.ACTIVE_ONLY,
        max_results=top_n,
        order_by=["metrics.rmse ASC"]
    )

    # Train and log models from HPO experiment
    for run in runs:
        print(run)
        params = run.data.params
        print(params)
        # Convert parameter values from strings to appropriate types
        params = {key: eval(value) if value.isdigit() else value for key, value in params.items() if key in RF_PARAMS}
        train_and_log_model(data_path=data_path, params=params)

    # Select the model with the lowest test RMSE from the main experiment
    main_experiment = client.get_experiment_by_name(HPO_EXPERIMENT_NAME)
    if main_experiment is None:
        raise ValueError(f"Experiment '{HPO_EXPERIMENT_NAME}' not found.")

    all_runs = client.search_runs(
        experiment_ids=main_experiment.experiment_id,
        run_view_type=ViewType.ACTIVE_ONLY
    )

    print(all_runs)

    if not all_runs:
        raise ValueError(f"No runs found in experiment '{HPO_EXPERIMENT_NAME}'.")

    best_run = client.search_runs(
        experiment_ids=main_experiment.experiment_id,
        run_view_type=ViewType.ACTIVE_ONLY,
        max_results=1,
        order_by=["metrics.test_rmse ASC"]
    )[0]

    best_run_id = best_run.info.run_id

    # Register the best model
    model_uri = f"runs:/{best_run_id}/models_pickle/random_forest_model.pkl"

    print(model_uri)
    mlflow.register_model(model_uri=model_uri, name=MODEL_NAME)

# %%
data_path = "/data2"
run_register_model(data_path, top_n=5)
# Out:
# <Run: data=<RunData: metrics={'mean_squared_error_X_val': 5.370086069268862,
#  'rmse': 5.370086069268862,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "046a7431175442d88ad5693cbf17ff5b", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:24:40.963612", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"06502d6355e243758e67983593882668", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'victorious-hare-643',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForest'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/046a7431175442d88ad5693cbf17ff5b/artifacts', end_time=1717097100687, experiment_id='3', lifecycle_stage='active', run_id='046a7431175442d88ad5693cbf17ff5b', run_name='victorious-hare-643', run_uuid='046a7431175442d88ad5693cbf17ff5b', start_time=1717097067384, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# {'max_depth': '13', 'min_samples_leaf': '4', 'min_samples_split': '7', 'n_estimators': '43', 'random_state': '42', 'bootstrap': 'True', 'ccp_alpha': '0.0', 'criterion': 'squared_error', 'max_features': '1.0', 'max_leaf_nodes': 'None', 'max_samples': 'None', 'min_impurity_decrease': '0.0', 'min_weight_fraction_leaf': '0.0', 'monotonic_cst': 'None', 'n_jobs': 'None', 'oob_score': 'False', 'verbose': '0', 'warm_start': 'False'}
# 2024/05/30 22:58:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# <Run: data=<RunData: metrics={'mean_squared_error_X_val': 6.336044899923993,
#  'rmse': 6.336044899923993,
#  'training_mean_absolute_error': 4.219143142306118,
#  'training_mean_squared_error': 38.96874159510181,
#  'training_r2_score': 0.5214326108989062,
#  'training_root_mean_squared_error': 6.242494821391669,
#  'training_score': 0.5214326108989062}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '2',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '22',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "abe2e1dbcbf94f79ba3f4334b0f707bd", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:25:01.858535", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"692a6b8a72914b81ba30af66db6e5183", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'abrasive-hen-757',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForest'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/abe2e1dbcbf94f79ba3f4334b0f707bd/artifacts', end_time=1717097109418, experiment_id='3', lifecycle_stage='active', run_id='abe2e1dbcbf94f79ba3f4334b0f707bd', run_name='abrasive-hen-757', run_uuid='abe2e1dbcbf94f79ba3f4334b0f707bd', start_time=1717097100730, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# {'max_depth': '2', 'min_samples_leaf': '4', 'min_samples_split': '7', 'n_estimators': '22', 'random_state': '42', 'bootstrap': 'True', 'ccp_alpha': '0.0', 'criterion': 'squared_error', 'max_features': '1.0', 'max_leaf_nodes': 'None', 'max_samples': 'None', 'min_impurity_decrease': '0.0', 'min_weight_fraction_leaf': '0.0', 'monotonic_cst': 'None', 'n_jobs': 'None', 'oob_score': 'False', 'verbose': '0', 'warm_start': 'False'}
# 2024/05/30 22:59:22 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "839036dce9bc45b5ae9a8f2c08a82e7b", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:56:54.624657", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"f934c303c52448dc963ea5990fd9f0a4", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'casual-elk-157',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/839036dce9bc45b5ae9a8f2c08a82e7b/artifacts', end_time=1717099023582, experiment_id='3', lifecycle_stage='active', run_id='839036dce9bc45b5ae9a8f2c08a82e7b', run_name='casual-elk-157', run_uuid='839036dce9bc45b5ae9a8f2c08a82e7b', start_time=1717099001049, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# {'max_depth': '13', 'min_samples_leaf': '4', 'min_samples_split': '7', 'n_estimators': '43', 'random_state': '42', 'bootstrap': 'True', 'ccp_alpha': '0.0', 'criterion': 'squared_error', 'max_features': '1.0', 'max_leaf_nodes': 'None', 'max_samples': 'None', 'min_impurity_decrease': '0.0', 'min_weight_fraction_leaf': '0.0', 'monotonic_cst': 'None', 'n_jobs': 'None', 'oob_score': 'False', 'verbose': '0', 'warm_start': 'False'}
# 2024/05/30 22:59:34 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 6.606223294805459,
#  'mean_squared_error_X_val': 6.336044899923993,
#  'test_rmse': 6.606223294805459,
#  'training_mean_absolute_error': 4.219143142306118,
#  'training_mean_squared_error': 38.96874159510181,
#  'training_r2_score': 0.5214326108989062,
#  'training_root_mean_squared_error': 6.242494821391669,
#  'training_score': 0.5214326108989062,
#  'val_rmse': 6.336044899923993}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '2',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '22',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "9e7324eba2c547cb8e43d38883b08853", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:56:31.790618", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"1ffe9a8f98fe4131ad3b8bf2d16f47b0", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'enthused-snipe-290',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/9e7324eba2c547cb8e43d38883b08853/artifacts', end_time=1717099001019, experiment_id='3', lifecycle_stage='active', run_id='9e7324eba2c547cb8e43d38883b08853', run_name='enthused-snipe-290', run_uuid='9e7324eba2c547cb8e43d38883b08853', start_time=1717098990795, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# {'max_depth': '2', 'min_samples_leaf': '4', 'min_samples_split': '7', 'n_estimators': '22', 'random_state': '42', 'bootstrap': 'True', 'ccp_alpha': '0.0', 'criterion': 'squared_error', 'max_features': '1.0', 'max_leaf_nodes': 'None', 'max_samples': 'None', 'min_impurity_decrease': '0.0', 'min_weight_fraction_leaf': '0.0', 'monotonic_cst': 'None', 'n_jobs': 'None', 'oob_score': 'False', 'verbose': '0', 'warm_start': 'False'}
# 2024/05/30 22:59:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "8881bfa27ac34a6895b21b8adbc1573e", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:56:21.522431", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"3fb9e2cb1cc540fb8b75e5f8f4570e0e", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'calm-sponge-22',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/8881bfa27ac34a6895b21b8adbc1573e/artifacts', end_time=1717098990766, experiment_id='3', lifecycle_stage='active', run_id='8881bfa27ac34a6895b21b8adbc1573e', run_name='calm-sponge-22', run_uuid='8881bfa27ac34a6895b21b8adbc1573e', start_time=1717098968188, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>
# {'max_depth': '13', 'min_samples_leaf': '4', 'min_samples_split': '7', 'n_estimators': '43', 'random_state': '42', 'bootstrap': 'True', 'ccp_alpha': '0.0', 'criterion': 'squared_error', 'max_features': '1.0', 'max_leaf_nodes': 'None', 'max_samples': 'None', 'min_impurity_decrease': '0.0', 'min_weight_fraction_leaf': '0.0', 'monotonic_cst': 'None', 'n_jobs': 'None', 'oob_score': 'False', 'verbose': '0', 'warm_start': 'False'}
# 2024/05/30 23:00:07 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Registered model 'random-forest' already exists. Creating a new version of this model...
# 2024/05/30 23:00:29 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: random-forest, version 2
# [<Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "8cb0414c9fa6489da1a9e086b3383438", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 20:00:20.377610", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"34d8138795ef4e2291aaeef49a93aa37", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'placid-stork-209',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/8cb0414c9fa6489da1a9e086b3383438/artifacts', end_time=1717099229085, experiment_id='3', lifecycle_stage='active', run_id='8cb0414c9fa6489da1a9e086b3383438', run_name='placid-stork-209', run_uuid='8cb0414c9fa6489da1a9e086b3383438', start_time=1717099207123, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 6.606223294805459,
#  'mean_squared_error_X_val': 6.336044899923993,
#  'test_rmse': 6.606223294805459,
#  'training_mean_absolute_error': 4.219143142306118,
#  'training_mean_squared_error': 38.96874159510181,
#  'training_r2_score': 0.5214326108989062,
#  'training_root_mean_squared_error': 6.242494821391669,
#  'training_score': 0.5214326108989062,
#  'val_rmse': 6.336044899923993}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '2',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '22',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "e3250c762d7d4deb967506ab415fed61", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:59:59.029219", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"82e29115b9484e48ba5f50558db5a083", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'gifted-foal-825',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/e3250c762d7d4deb967506ab415fed61/artifacts', end_time=1717099207094, experiment_id='3', lifecycle_stage='active', run_id='e3250c762d7d4deb967506ab415fed61', run_name='gifted-foal-825', run_uuid='e3250c762d7d4deb967506ab415fed61', start_time=1717099198050, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "431e0ae4f6e94d54927c40683f4f14d8", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:59:47.674314", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"87ceab8d9b494f83a697f980df4f18f8", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'powerful-boar-78',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/431e0ae4f6e94d54927c40683f4f14d8/artifacts', end_time=1717099198020, experiment_id='3', lifecycle_stage='active', run_id='431e0ae4f6e94d54927c40683f4f14d8', run_name='powerful-boar-78', run_uuid='431e0ae4f6e94d54927c40683f4f14d8', start_time=1717099174147, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 6.606223294805459,
#  'mean_squared_error_X_val': 6.336044899923993,
#  'test_rmse': 6.606223294805459,
#  'training_mean_absolute_error': 4.219143142306118,
#  'training_mean_squared_error': 38.96874159510181,
#  'training_r2_score': 0.5214326108989062,
#  'training_root_mean_squared_error': 6.242494821391669,
#  'training_score': 0.5214326108989062,
#  'val_rmse': 6.336044899923993}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '2',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '22',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "1e4a17a905ac402dbfb10140e8eb9f46", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:59:23.500579", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"be10ce34737c454780dacbbc02bc47de", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'mercurial-newt-419',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/1e4a17a905ac402dbfb10140e8eb9f46/artifacts', end_time=1717099174115, experiment_id='3', lifecycle_stage='active', run_id='1e4a17a905ac402dbfb10140e8eb9f46', run_name='mercurial-newt-419', run_uuid='1e4a17a905ac402dbfb10140e8eb9f46', start_time=1717099162457, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "144e8570f29b41ffb9ecb153fa048326", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:59:12.144375", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"f536afdf52ff4e28912a653e62155190", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'abundant-kit-745',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
# ...
#                              'null}}, "model_uuid": '
#                              '"41a9f835aae14296a8beb51395321bc7", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'valuable-midge-150',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/3acf0fd6d6364523b34d3375d52d0b5e/artifacts', end_time=1717097993660, experiment_id='3', lifecycle_stage='active', run_id='3acf0fd6d6364523b34d3375d52d0b5e', run_name='valuable-midge-150', run_uuid='3acf0fd6d6364523b34d3375d52d0b5e', start_time=1717097982769, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error-2_X_test': 5.599280662415257,
#  'mean_squared_error_X_val': 5.370086069268862,
#  'test_rmse': 5.599280662415257,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566,
#  'val_rmse': 5.370086069268862}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "46a4d3e928864009bce461e263b6df08", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:39:27.897333", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"79322fb64bc54ce9a8c34603c6907668", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'melodic-shrew-636',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/46a4d3e928864009bce461e263b6df08/artifacts', end_time=1717097982725, experiment_id='3', lifecycle_stage='active', run_id='46a4d3e928864009bce461e263b6df08', run_name='melodic-shrew-636', run_uuid='46a4d3e928864009bce461e263b6df08', start_time=1717097954396, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>,
#  <DatasetInput: dataset=<Dataset: digest='5a2feb47', name='dataset', profile=('{"features_shape": [69392, 5702], "features_size": 395673184, '
#  '"features_nbytes": 3165385472}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.runName': 'redolent-wren-374',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForestRegressor'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/35b17af834444fae843572f13333b4e3/artifacts', end_time=1717097165646, experiment_id='3', lifecycle_stage='active', run_id='35b17af834444fae843572f13333b4e3', run_name='redolent-wren-374', run_uuid='35b17af834444fae843572f13333b4e3', start_time=1717097165317, status='FAILED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[]>>, <Run: data=<RunData: metrics={'mean_squared_error_X_val': 6.336044899923993,
#  'rmse': 6.336044899923993,
#  'training_mean_absolute_error': 4.219143142306118,
#  'training_mean_squared_error': 38.96874159510181,
#  'training_r2_score': 0.5214326108989062,
#  'training_root_mean_squared_error': 6.242494821391669,
#  'training_score': 0.5214326108989062}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '2',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '22',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "abe2e1dbcbf94f79ba3f4334b0f707bd", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:25:01.858535", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"692a6b8a72914b81ba30af66db6e5183", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '17677}]',
#  'mlflow.runName': 'abrasive-hen-757',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForest'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/abe2e1dbcbf94f79ba3f4334b0f707bd/artifacts', end_time=1717097109418, experiment_id='3', lifecycle_stage='active', run_id='abe2e1dbcbf94f79ba3f4334b0f707bd', run_name='abrasive-hen-757', run_uuid='abe2e1dbcbf94f79ba3f4334b0f707bd', start_time=1717097100730, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>, <Run: data=<RunData: metrics={'mean_squared_error_X_val': 5.370086069268862,
#  'rmse': 5.370086069268862,
#  'training_mean_absolute_error': 3.341844396061385,
#  'training_mean_squared_error': 26.75293577873919,
#  'training_r2_score': 0.6714525000717566,
#  'training_root_mean_squared_error': 5.172324021050807,
#  'training_score': 0.6714525000717566}, params={'bootstrap': 'True',
#  'ccp_alpha': '0.0',
#  'criterion': 'squared_error',
#  'max_depth': '13',
#  'max_features': '1.0',
#  'max_leaf_nodes': 'None',
#  'max_samples': 'None',
#  'min_impurity_decrease': '0.0',
#  'min_samples_leaf': '4',
#  'min_samples_split': '7',
#  'min_weight_fraction_leaf': '0.0',
#  'monotonic_cst': 'None',
#  'n_estimators': '43',
#  'n_jobs': 'None',
#  'oob_score': 'False',
#  'random_state': '42',
#  'verbose': '0',
#  'warm_start': 'False'}, tags={'estimator_class': 'sklearn.ensemble._forest.RandomForestRegressor',
#  'estimator_name': 'RandomForestRegressor',
#  'mlflow.log-model.history': '[{"run_id": "046a7431175442d88ad5693cbf17ff5b", '
#                              '"artifact_path": "model", "utc_time_created": '
#                              '"2024-05-30 19:24:40.963612", "flavors": '
#                              '{"python_function": {"model_path": "model.pkl", '
#                              '"predict_fn": "predict", "loader_module": '
#                              '"mlflow.sklearn", "python_version": "3.9.13", '
#                              '"env": {"conda": "conda.yaml", "virtualenv": '
#                              '"python_env.yaml"}}, "sklearn": '
#                              '{"pickled_model": "model.pkl", '
#                              '"sklearn_version": "1.5.0", '
#                              '"serialization_format": "cloudpickle", "code": '
#                              'null}}, "model_uuid": '
#                              '"06502d6355e243758e67983593882668", '
#                              '"mlflow_version": "2.13.0", "signature": '
#                              '{"inputs": "[{\\"type\\": \\"tensor\\", '
#                              '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", '
#                              '\\"shape\\": [-1, 5702]}}]", "outputs": '
#                              '"[{\\"type\\": \\"tensor\\", \\"tensor-spec\\": '
#                              '{\\"dtype\\": \\"float64\\", \\"shape\\": '
#                              '[-1]}}]", "params": null}, "model_size_bytes": '
#                              '4031737}]',
#  'mlflow.runName': 'victorious-hare-643',
#  'mlflow.source.name': 'c:\\Users\\ASUS\\Documents\\GitHub\\mlops-zoomcamp\\.venv\\lib\\site-packages\\ipykernel_launcher.py',
#  'mlflow.source.type': 'LOCAL',
#  'mlflow.user': 'ASUS',
#  'model': 'RandomForest'}>, info=<RunInfo: artifact_uri='mlflow-artifacts:/3/046a7431175442d88ad5693cbf17ff5b/artifacts', end_time=1717097100687, experiment_id='3', lifecycle_stage='active', run_id='046a7431175442d88ad5693cbf17ff5b', run_name='victorious-hare-643', run_uuid='046a7431175442d88ad5693cbf17ff5b', start_time=1717097067384, status='FINISHED', user_id='ASUS'>, inputs=<RunInputs: dataset_inputs=[<DatasetInput: dataset=<Dataset: digest='7edda543', name='dataset', profile=('{"features_shape": [62574, 5702], "features_size": 356796948, '
#  '"features_nbytes": 2854375584}'), schema=('{"mlflow_tensorspec": {"features": "[{\\"type\\": \\"tensor\\", '
#  '\\"tensor-spec\\": {\\"dtype\\": \\"float64\\", \\"shape\\": [-1, 5702]}}]", '
#  '"targets": null}}'), source=('{"tags": {"mlflow.user": "ASUS", "mlflow.source.name": '
#  '"c:\\\\Users\\\\ASUS\\\\Documents\\\\GitHub\\\\mlops-zoomcamp\\\\.venv\\\\lib\\\\site-packages\\\\ipykernel_launcher.py", '
#  '"mlflow.source.type": "LOCAL"}}'), source_type='code'>, tags=[<InputTag: key='mlflow.data.context', value='eval'>]>]>>]
# runs:/8cb0414c9fa6489da1a9e086b3383438/models_pickle/random_forest_model.pkl
# Created version '2' of model 'random-forest'.
