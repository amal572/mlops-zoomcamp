# %%
# !python -V
# Out:
# Python 3.9.13

# %%
import pandas as pd
import pickle
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error
import mlflow
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
mlflow.set_tracking_uri("sqlite:///data/mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='file:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/mlruns/1', creation_time=1716931336348, experiment_id='1', last_update_time=1716931336348, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df_train = pd.read_parquet('green_tripdata_2021-01.parquet')
df_val = pd.read_parquet('green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (76518, 64572)

# %%
df_train.lpep_dropoff_datetime = pd.to_datetime(df_train.lpep_dropoff_datetime)
df_train.lpep_pickup_datetime = pd.to_datetime(df_train.lpep_pickup_datetime)

df_train['duration'] = df_train.lpep_dropoff_datetime - df_train.lpep_pickup_datetime
df_train.duration = df_train.duration.apply(lambda td: td.total_seconds() / 60)

df_train = df_train[(df_train.duration >= 1) & (df_train.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
df_train[categorical] = df_train[categorical].astype(str)

# %%
df_val.lpep_dropoff_datetime = pd.to_datetime(df_val.lpep_dropoff_datetime)
df_val.lpep_pickup_datetime = pd.to_datetime(df_val.lpep_pickup_datetime)

df_val['duration'] = df_val.lpep_dropoff_datetime - df_val.lpep_pickup_datetime
df_val.duration = df_val.duration.apply(lambda td: td.total_seconds() / 60)

df_val = df_val[(df_val.duration >= 1) & (df_val.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
df_val[categorical] = df_val[categorical].astype(str)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.758715203341164

# %%
with open('mlruns/models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")

    alpha = 0.1
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="mlruns/models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# %%
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\xgboost\core.py:160: UserWarning: [00:50:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0b3782d1791676daf-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.47445
# [1]	validation-rmse:10.82465
# [2]	validation-rmse:10.25534
# [3]	validation-rmse:9.75806
# [4]	validation-rmse:9.32445
# [5]	validation-rmse:8.94854
# [6]	validation-rmse:8.62318
# [7]	validation-rmse:8.34218
# [8]	validation-rmse:8.10125
# [9]	validation-rmse:7.89460
# [10]	validation-rmse:7.71781
# [11]	validation-rmse:7.56630
# [12]	validation-rmse:7.43657
# [13]	validation-rmse:7.32636
# [14]	validation-rmse:7.23153
# [15]	validation-rmse:7.15027
# [16]	validation-rmse:7.08158
# [17]	validation-rmse:7.02252
# [18]	validation-rmse:6.97187
# [19]	validation-rmse:6.92749
# [20]	validation-rmse:6.88947
# [21]	validation-rmse:6.85782
# [22]	validation-rmse:6.82896
# [23]	validation-rmse:6.80436
# [24]	validation-rmse:6.78310
# [25]	validation-rmse:6.76456
# [26]	validation-rmse:6.74868
# [27]	validation-rmse:6.73454
# [28]	validation-rmse:6.72192
# [29]	validation-rmse:6.71058
# [30]	validation-rmse:6.70094
# [31]	validation-rmse:6.69247
# [32]	validation-rmse:6.68510
# [33]	validation-rmse:6.67832
# [34]	validation-rmse:6.67218
# [35]	validation-rmse:6.66670
# [36]	validation-rmse:6.66183
# [37]	validation-rmse:6.65702
# [38]	validation-rmse:6.65303
# [39]	validation-rmse:6.64901
# [40]	validation-rmse:6.64549
# [41]	validation-rmse:6.64235
# [42]	validation-rmse:6.63964
# [43]	validation-rmse:6.63704
# [44]	validation-rmse:6.63417
# [45]	validation-rmse:6.63177
# [46]	validation-rmse:6.62986
# [47]	validation-rmse:6.62788
# [48]	validation-rmse:6.62622
# [49]	validation-rmse:6.62459
# [50]	validation-rmse:6.62318
# [51]	validation-rmse:6.62176
# [52]	validation-rmse:6.62088
# [53]	validation-rmse:6.61935
# [54]	validation-rmse:6.61813
# [55]	validation-rmse:6.61759
# [56]	validation-rmse:6.61710
# [57]	validation-rmse:6.61646
# [58]	validation-rmse:6.61489
# [59]	validation-rmse:6.61378
# [60]	validation-rmse:6.61303
# [61]	validation-rmse:6.61200
# [62]	validation-rmse:6.61138
# [63]	validation-rmse:6.61052
# [64]	validation-rmse:6.60987
# [65]	validation-rmse:6.60938
# [66]	validation-rmse:6.60891
# [67]	validation-rmse:6.60818
# [68]	validation-rmse:6.60746
# [69]	validation-rmse:6.60700
# [70]	validation-rmse:6.60626
# [71]	validation-rmse:6.60583
# [72]	validation-rmse:6.60528
# [73]	validation-rmse:6.60438
# [74]	validation-rmse:6.60382
# [75]	validation-rmse:6.60293
# [76]	validation-rmse:6.60252
# [77]	validation-rmse:6.60196
# [78]	validation-rmse:6.60169
# [79]	validation-rmse:6.60120
# [80]	validation-rmse:6.60069
# [81]	validation-rmse:6.60004
# [82]	validation-rmse:6.59982
# [83]	validation-rmse:6.59921
# [84]	validation-rmse:6.59884
# [85]	validation-rmse:6.59824
# [86]	validation-rmse:6.59786
# [87]	validation-rmse:6.59745
# [88]	validation-rmse:6.59666
# [89]	validation-rmse:6.59641
# [90]	validation-rmse:6.59608
# [91]	validation-rmse:6.59565
# [92]	validation-rmse:6.59527
# [93]	validation-rmse:6.59490
# [94]	validation-rmse:6.59417
# [95]	validation-rmse:6.59378
# [96]	validation-rmse:6.59351
# [97]	validation-rmse:6.59299
# [98]	validation-rmse:6.59275
# [99]	validation-rmse:6.59228
# [100]	validation-rmse:6.59197
# [101]	validation-rmse:6.59151
# [102]	validation-rmse:6.59117
# [103]	validation-rmse:6.59067
# [104]	validation-rmse:6.59044
# [105]	validation-rmse:6.59016
# [106]	validation-rmse:6.58989
# [107]	validation-rmse:6.58953
# [108]	validation-rmse:6.58920
# [109]	validation-rmse:6.58888
# [110]	validation-rmse:6.58849
# [111]	validation-rmse:6.58821
# [112]	validation-rmse:6.58770
# [113]	validation-rmse:6.58744
# [114]	validation-rmse:6.58684
# [115]	validation-rmse:6.58665
# [116]	validation-rmse:6.58638
# [117]	validation-rmse:6.58610
# [118]	validation-rmse:6.58575
# [119]	validation-rmse:6.58536
# [120]	validation-rmse:6.58488
# [121]	validation-rmse:6.58455
# [122]	validation-rmse:6.58435
# [123]	validation-rmse:6.58398
# [124]	validation-rmse:6.58354
# [125]	validation-rmse:6.58312
# [126]	validation-rmse:6.58290
# [127]	validation-rmse:6.58258
# [128]	validation-rmse:6.58244
# [129]	validation-rmse:6.58217
# [130]	validation-rmse:6.58195
# [131]	validation-rmse:6.58159
# [132]	validation-rmse:6.58134
# [133]	validation-rmse:6.58111
# [134]	validation-rmse:6.58084
# [135]	validation-rmse:6.58069
# [136]	validation-rmse:6.58022
# [137]	validation-rmse:6.57998
# [138]	validation-rmse:6.57943
# [139]	validation-rmse:6.57920
# [140]	validation-rmse:6.57894
# [141]	validation-rmse:6.57868
# [142]	validation-rmse:6.57850
# [143]	validation-rmse:6.57821
# [144]	validation-rmse:6.57779
# [145]	validation-rmse:6.57755
# [146]	validation-rmse:6.57735
# [147]	validation-rmse:6.57713
# [148]	validation-rmse:6.57687
# [149]	validation-rmse:6.57652
# [150]	validation-rmse:6.57625
# [151]	validation-rmse:6.57611
# [152]	validation-rmse:6.57574
# [153]	validation-rmse:6.57551
# [154]	validation-rmse:6.57529
# [155]	validation-rmse:6.57515
# [156]	validation-rmse:6.57475
# [157]	validation-rmse:6.57447
# [158]	validation-rmse:6.57435
# [159]	validation-rmse:6.57416
# [160]	validation-rmse:6.57388
# [161]	validation-rmse:6.57364
# [162]	validation-rmse:6.57349
# [163]	validation-rmse:6.57325
# [164]	validation-rmse:6.57309
# [165]	validation-rmse:6.57255
# [166]	validation-rmse:6.57226
# [167]	validation-rmse:6.57212
# [168]	validation-rmse:6.57181
# [169]	validation-rmse:6.57154
# [170]	validation-rmse:6.57143
# [171]	validation-rmse:6.57123
# [172]	validation-rmse:6.57096
# [173]	validation-rmse:6.57083
# [174]	validation-rmse:6.57070
# [175]	validation-rmse:6.57052
# [176]	validation-rmse:6.57033
# [177]	validation-rmse:6.57006
# [178]	validation-rmse:6.56991
# [179]	validation-rmse:6.56970
# [180]	validation-rmse:6.56941
# [181]	validation-rmse:6.56928
# [182]	validation-rmse:6.56896
# [183]	validation-rmse:6.56877
# [184]	validation-rmse:6.56854
# [185]	validation-rmse:6.56770
# [186]	validation-rmse:6.56743
# [187]	validation-rmse:6.56728
# [188]	validation-rmse:6.56701
# [189]	validation-rmse:6.56669
# [190]	validation-rmse:6.56661
# [191]	validation-rmse:6.56645
# [192]	validation-rmse:6.56626
# [193]	validation-rmse:6.56592
# [194]	validation-rmse:6.56571
# [195]	validation-rmse:6.56560
# [196]	validation-rmse:6.56543
# [197]	validation-rmse:6.56526
# [198]	validation-rmse:6.56503
# [199]	validation-rmse:6.56485
# [200]	validation-rmse:6.56458
# [473]	validation-rmse:6.52766
# [474]	validation-rmse:6.52758
# [475]	validation-rmse:6.52758
# [476]	validation-rmse:6.52746
# [477]	validation-rmse:6.52733
# [478]	validation-rmse:6.52721
# [479]	validation-rmse:6.52710
# [480]	validation-rmse:6.52703
# [481]	validation-rmse:6.52701
# [482]	validation-rmse:6.52681
# [483]	validation-rmse:6.52673
# [484]	validation-rmse:6.52674
# [485]	validation-rmse:6.52668
# [486]	validation-rmse:6.52664
# [487]	validation-rmse:6.52663
# [488]	validation-rmse:6.52637
# [489]	validation-rmse:6.52634
# [490]	validation-rmse:6.52627
# [491]	validation-rmse:6.52618
# [492]	validation-rmse:6.52608
# [493]	validation-rmse:6.52608
# [494]	validation-rmse:6.52597
# [495]	validation-rmse:6.52591
# [496]	validation-rmse:6.52591
# [497]	validation-rmse:6.52583
# [498]	validation-rmse:6.52579
# [499]	validation-rmse:6.52568
# [500]	validation-rmse:6.52556
# [501]	validation-rmse:6.52547
# [502]	validation-rmse:6.52541
# [503]	validation-rmse:6.52539
# [504]	validation-rmse:6.52542
# [505]	validation-rmse:6.52539
# [506]	validation-rmse:6.52536
# [507]	validation-rmse:6.52529
# [508]	validation-rmse:6.52530
# [509]	validation-rmse:6.52518
# [510]	validation-rmse:6.52506
# [511]	validation-rmse:6.52499
# [512]	validation-rmse:6.52485
# [513]	validation-rmse:6.52480
# [514]	validation-rmse:6.52480
# [515]	validation-rmse:6.52479
# [516]	validation-rmse:6.52463
# [517]	validation-rmse:6.52465
# [518]	validation-rmse:6.52457
# [519]	validation-rmse:6.52453
# [520]	validation-rmse:6.52436
# [521]	validation-rmse:6.52424
# [522]	validation-rmse:6.52400
# [523]	validation-rmse:6.52401
# [524]	validation-rmse:6.52399
# [525]	validation-rmse:6.52396
# [526]	validation-rmse:6.52396
# [527]	validation-rmse:6.52384
# [528]	validation-rmse:6.52385
# [529]	validation-rmse:6.52381
# [530]	validation-rmse:6.52373
# [531]	validation-rmse:6.52366
# [532]	validation-rmse:6.52373
# [533]	validation-rmse:6.52368
# [534]	validation-rmse:6.52345
# [535]	validation-rmse:6.52327
# [536]	validation-rmse:6.52322
# [537]	validation-rmse:6.52305
# [538]	validation-rmse:6.52296
# [539]	validation-rmse:6.52289
# [540]	validation-rmse:6.52288
# [541]	validation-rmse:6.52280
# [542]	validation-rmse:6.52276
# [543]	validation-rmse:6.52273
# [544]	validation-rmse:6.52268
# [545]	validation-rmse:6.52267
# [546]	validation-rmse:6.52267
# [547]	validation-rmse:6.52266
# [548]	validation-rmse:6.52261
# [549]	validation-rmse:6.52254
# [550]	validation-rmse:6.52238
# [551]	validation-rmse:6.52234
# [552]	validation-rmse:6.52237
# [553]	validation-rmse:6.52240
# [554]	validation-rmse:6.52236
# [555]	validation-rmse:6.52227
# [556]	validation-rmse:6.52219
# [557]	validation-rmse:6.52215
# [558]	validation-rmse:6.52210
# [559]	validation-rmse:6.52200
# [560]	validation-rmse:6.52199
# [561]	validation-rmse:6.52197
# [562]	validation-rmse:6.52188
# [563]	validation-rmse:6.52187
# [564]	validation-rmse:6.52156
# [565]	validation-rmse:6.52143
# [566]	validation-rmse:6.52128
# [567]	validation-rmse:6.52124
# [568]	validation-rmse:6.52123
# [569]	validation-rmse:6.52119
# [570]	validation-rmse:6.52116
# [571]	validation-rmse:6.52109
# [572]	validation-rmse:6.52110
# [573]	validation-rmse:6.52108
# [574]	validation-rmse:6.52103
# [575]	validation-rmse:6.52092
# [576]	validation-rmse:6.52084
# [577]	validation-rmse:6.52074
# [578]	validation-rmse:6.52073
# [579]	validation-rmse:6.52068
# [580]	validation-rmse:6.52060
# [581]	validation-rmse:6.52060
# [582]	validation-rmse:6.52053
# [583]	validation-rmse:6.52052
# [584]	validation-rmse:6.52055
# [585]	validation-rmse:6.52052
# [586]	validation-rmse:6.52047
# [587]	validation-rmse:6.52039
# [588]	validation-rmse:6.52033
# [589]	validation-rmse:6.52027
# [590]	validation-rmse:6.52023
# [591]	validation-rmse:6.52025
# [592]	validation-rmse:6.52020
# [593]	validation-rmse:6.52021
# [594]	validation-rmse:6.52017
# [595]	validation-rmse:6.52007
# [596]	validation-rmse:6.51996
# [597]	validation-rmse:6.51998
# [598]	validation-rmse:6.51999
# [599]	validation-rmse:6.51996
# [600]	validation-rmse:6.51996
# [601]	validation-rmse:6.51995
# [602]	validation-rmse:6.51992
# [603]	validation-rmse:6.51979
# [604]	validation-rmse:6.51964
# [605]	validation-rmse:6.51944
# [606]	validation-rmse:6.51935
# [607]	validation-rmse:6.51924
# [608]	validation-rmse:6.51924
# [609]	validation-rmse:6.51921
# [610]	validation-rmse:6.51914
# [611]	validation-rmse:6.51909
# [612]	validation-rmse:6.51905
# [613]	validation-rmse:6.51899
# [614]	validation-rmse:6.51892
# [615]	validation-rmse:6.51888
# [616]	validation-rmse:6.51876
# [617]	validation-rmse:6.51874
# [618]	validation-rmse:6.51871
# [619]	validation-rmse:6.51842
# [620]	validation-rmse:6.51815
# [621]	validation-rmse:6.51813
# [622]	validation-rmse:6.51805
# [623]	validation-rmse:6.51800
# [624]	validation-rmse:6.51790
# [625]	validation-rmse:6.51791
# [626]	validation-rmse:6.51786
# [627]	validation-rmse:6.51783
# [628]	validation-rmse:6.51781
# [629]	validation-rmse:6.51780
# [630]	validation-rmse:6.51778
# [631]	validation-rmse:6.51772
# [632]	validation-rmse:6.51767
# [633]	validation-rmse:6.51766
# [634]	validation-rmse:6.51764
# [635]	validation-rmse:6.51758
# [636]	validation-rmse:6.51765
# [637]	validation-rmse:6.51760
# [638]	validation-rmse:6.51754
# [639]	validation-rmse:6.51746
# [640]	validation-rmse:6.51737
# [641]	validation-rmse:6.51732
# [642]	validation-rmse:6.51731
# [643]	validation-rmse:6.51711
# [644]	validation-rmse:6.51707
# [645]	validation-rmse:6.51709
# [646]	validation-rmse:6.51706
# [647]	validation-rmse:6.51707
# [648]	validation-rmse:6.51697
# [649]	validation-rmse:6.51693
# [650]	validation-rmse:6.51686
# [651]	validation-rmse:6.51679
# [652]	validation-rmse:6.51680
# [653]	validation-rmse:6.51671
# [654]	validation-rmse:6.51667
# [655]	validation-rmse:6.51662
# [656]	validation-rmse:6.51654
# [657]	validation-rmse:6.51648
# [658]	validation-rmse:6.51643
# [659]	validation-rmse:6.51639
# [660]	validation-rmse:6.51632
# [661]	validation-rmse:6.51629
# [662]	validation-rmse:6.51634
# [663]	validation-rmse:6.51634
# [664]	validation-rmse:6.51632
# [665]	validation-rmse:6.51625
# [666]	validation-rmse:6.51620
# [667]	validation-rmse:6.51616
# [668]	validation-rmse:6.51616
# [669]	validation-rmse:6.51621
# [670]	validation-rmse:6.51618
# [671]	validation-rmse:6.51611
# [672]	validation-rmse:6.51605
# [673]	validation-rmse:6.51604
# [674]	validation-rmse:6.51607
# [675]	validation-rmse:6.51604
# [676]	validation-rmse:6.51590
# [677]	validation-rmse:6.51588
# [678]	validation-rmse:6.51576
# [679]	validation-rmse:6.51571
# [680]	validation-rmse:6.51575
# [681]	validation-rmse:6.51575
# [682]	validation-rmse:6.51568
# [683]	validation-rmse:6.51566
# [684]	validation-rmse:6.51565
# [685]	validation-rmse:6.51568
# [686]	validation-rmse:6.51568
# [687]	validation-rmse:6.51564
# [688]	validation-rmse:6.51559
# [689]	validation-rmse:6.51555
# [690]	validation-rmse:6.51551
# [691]	validation-rmse:6.51550
# [692]	validation-rmse:6.51558
# [693]	validation-rmse:6.51550
# [694]	validation-rmse:6.51545
# [695]	validation-rmse:6.51539
# [696]	validation-rmse:6.51539
# [697]	validation-rmse:6.51534
# [698]	validation-rmse:6.51519
# [699]	validation-rmse:6.51517
# [700]	validation-rmse:6.51518
# [701]	validation-rmse:6.51513
# [702]	validation-rmse:6.51509
# [703]	validation-rmse:6.51512
# [704]	validation-rmse:6.51511
# [705]	validation-rmse:6.51508
# [706]	validation-rmse:6.51504
# [707]	validation-rmse:6.51505
# [708]	validation-rmse:6.51504
# [709]	validation-rmse:6.51501
# [710]	validation-rmse:6.51496
# [711]	validation-rmse:6.51493
# [712]	validation-rmse:6.51491
# [713]	validation-rmse:6.51488
# [714]	validation-rmse:6.51478
# [715]	validation-rmse:6.51474
# [716]	validation-rmse:6.51465
# [717]	validation-rmse:6.51462
# [718]	validation-rmse:6.51454
# [719]	validation-rmse:6.51450
# [720]	validation-rmse:6.51438
# [721]	validation-rmse:6.51431
# [722]	validation-rmse:6.51423
# [723]	validation-rmse:6.51423
# [724]	validation-rmse:6.51423
# [725]	validation-rmse:6.51420
# [726]	validation-rmse:6.51414
# [727]	validation-rmse:6.51405
# [728]	validation-rmse:6.51406
# [729]	validation-rmse:6.51402
# [730]	validation-rmse:6.51399
# [731]	validation-rmse:6.51393
# [732]	validation-rmse:6.51384
# [733]	validation-rmse:6.51381
# [734]	validation-rmse:6.51378
# [735]	validation-rmse:6.51375
# [736]	validation-rmse:6.51372
# [737]	validation-rmse:6.51369
# [738]	validation-rmse:6.51364
# [739]	validation-rmse:6.51355
# [740]	validation-rmse:6.51353
# [741]	validation-rmse:6.51334
# [742]	validation-rmse:6.51332
# [743]	validation-rmse:6.51310
# [744]	validation-rmse:6.51297
# [745]	validation-rmse:6.51283
# [746]	validation-rmse:6.51282
# [747]	validation-rmse:6.51271
# [748]	validation-rmse:6.51268
# [749]	validation-rmse:6.51257
# [750]	validation-rmse:6.51255
# [751]	validation-rmse:6.51254
# [752]	validation-rmse:6.51251
# [753]	validation-rmse:6.51249
# [754]	validation-rmse:6.51238
# [755]	validation-rmse:6.51237
# [756]	validation-rmse:6.51236
# [757]	validation-rmse:6.51235
# [758]	validation-rmse:6.51233
# [759]	validation-rmse:6.51231
# [760]	validation-rmse:6.51229
# [761]	validation-rmse:6.51231
# [762]	validation-rmse:6.51232
# [763]	validation-rmse:6.51226
# [764]	validation-rmse:6.51224
# [765]	validation-rmse:6.51220
# [766]	validation-rmse:6.51217
# [767]	validation-rmse:6.51208
# [768]	validation-rmse:6.51209
# [769]	validation-rmse:6.51205
# [770]	validation-rmse:6.51207
# [771]	validation-rmse:6.51205
# [772]	validation-rmse:6.51202
# [773]	validation-rmse:6.51196
# [774]	validation-rmse:6.51196
# [775]	validation-rmse:6.51195
# [776]	validation-rmse:6.51190
# [777]	validation-rmse:6.51187
# [778]	validation-rmse:6.51189
# [779]	validation-rmse:6.51185
# [780]	validation-rmse:6.51187
# [781]	validation-rmse:6.51187
# [782]	validation-rmse:6.51184
# [783]	validation-rmse:6.51179
# [784]	validation-rmse:6.51180
# [785]	validation-rmse:6.51177
# [786]	validation-rmse:6.51178
# [787]	validation-rmse:6.51175
# [788]	validation-rmse:6.51176
# [789]	validation-rmse:6.51177
# [790]	validation-rmse:6.51175
# [791]	validation-rmse:6.51168
# [792]	validation-rmse:6.51162
# [793]	validation-rmse:6.51160
# [794]	validation-rmse:6.51165
# [795]	validation-rmse:6.51164
# [796]	validation-rmse:6.51165
# [797]	validation-rmse:6.51159
# [798]	validation-rmse:6.51159
# [799]	validation-rmse:6.51149
# [800]	validation-rmse:6.51139
# [801]	validation-rmse:6.51135
# [802]	validation-rmse:6.51138
# [803]	validation-rmse:6.51129
# [804]	validation-rmse:6.51116
# [805]	validation-rmse:6.51111
# [806]	validation-rmse:6.51111
# [807]	validation-rmse:6.51108
# [808]	validation-rmse:6.51104
# [809]	validation-rmse:6.51096
# [810]	validation-rmse:6.51099
# [811]	validation-rmse:6.51100
# [812]	validation-rmse:6.51106
# [813]	validation-rmse:6.51107
# [814]	validation-rmse:6.51107
# [815]	validation-rmse:6.51104
# [816]	validation-rmse:6.51111
# [817]	validation-rmse:6.51108
# [818]	validation-rmse:6.51110
# [819]	validation-rmse:6.51105
# [820]	validation-rmse:6.51106
# [821]	validation-rmse:6.51100
# [822]	validation-rmse:6.51100
# [823]	validation-rmse:6.51092
# [824]	validation-rmse:6.51091
# [825]	validation-rmse:6.51095
# [826]	validation-rmse:6.51088
# [827]	validation-rmse:6.51086
# [828]	validation-rmse:6.51087
# [829]	validation-rmse:6.51083
# [830]	validation-rmse:6.51078
# [831]	validation-rmse:6.51072
# [832]	validation-rmse:6.51064
# [833]	validation-rmse:6.51057
# [834]	validation-rmse:6.51050
# [835]	validation-rmse:6.51045
# [836]	validation-rmse:6.51043
# [837]	validation-rmse:6.51040
# [838]	validation-rmse:6.51039
# [839]	validation-rmse:6.51038
# [840]	validation-rmse:6.51034
# [841]	validation-rmse:6.51031
# [842]	validation-rmse:6.51025
# [843]	validation-rmse:6.51021
# [844]	validation-rmse:6.51020
# [845]	validation-rmse:6.51017
# [846]	validation-rmse:6.51020
# [847]	validation-rmse:6.51019
# [848]	validation-rmse:6.51012
# [849]	validation-rmse:6.51015
# [850]	validation-rmse:6.51012
# [851]	validation-rmse:6.51013
# [852]	validation-rmse:6.51011
# [853]	validation-rmse:6.51009
# [854]	validation-rmse:6.51009
# [855]	validation-rmse:6.51003
# [856]	validation-rmse:6.50995
# [857]	validation-rmse:6.50991
# [858]	validation-rmse:6.50990
# [859]	validation-rmse:6.50991
# [860]	validation-rmse:6.51003
# [861]	validation-rmse:6.51000
# [862]	validation-rmse:6.51006
# [863]	validation-rmse:6.51005
# [864]	validation-rmse:6.51005
# ...
# [835]	validation-rmse:6.45242
# [836]	validation-rmse:6.45242
# [837]	validation-rmse:6.45240
# [838]	validation-rmse:6.45236
# [839]	validation-rmse:6.45224
# [840]	validation-rmse:6.45225
# [841]	validation-rmse:6.45220
# [842]	validation-rmse:6.45222
# [843]	validation-rmse:6.45219
# [844]	validation-rmse:6.45219
# [845]	validation-rmse:6.45218
# [846]	validation-rmse:6.45218
# [847]	validation-rmse:6.45210
# [848]	validation-rmse:6.45214
# [849]	validation-rmse:6.45210
# [850]	validation-rmse:6.45203
# [851]	validation-rmse:6.45201
# [852]	validation-rmse:6.45201
# [853]	validation-rmse:6.45200
# [854]	validation-rmse:6.45197
# [855]	validation-rmse:6.45196
# [856]	validation-rmse:6.45196
# [857]	validation-rmse:6.45195
# [858]	validation-rmse:6.45194
# [859]	validation-rmse:6.45195
# [860]	validation-rmse:6.45189
# [861]	validation-rmse:6.45187
# [862]	validation-rmse:6.45188
# [863]	validation-rmse:6.45187
# [864]	validation-rmse:6.45188
# [865]	validation-rmse:6.45185
# [866]	validation-rmse:6.45182
# [867]	validation-rmse:6.45182
# [868]	validation-rmse:6.45177
# [869]	validation-rmse:6.45168
# [870]	validation-rmse:6.45167
# [871]	validation-rmse:6.45167
# [872]	validation-rmse:6.45156
# [873]	validation-rmse:6.45156
# [874]	validation-rmse:6.45151
# [875]	validation-rmse:6.45145
# [876]	validation-rmse:6.45140
# [877]	validation-rmse:6.45128
# [878]	validation-rmse:6.45119
# [879]	validation-rmse:6.45117
# [880]	validation-rmse:6.45115
# [881]	validation-rmse:6.45109
# [882]	validation-rmse:6.45100
# [883]	validation-rmse:6.45097
# [884]	validation-rmse:6.45096
# [885]	validation-rmse:6.45102
# [886]	validation-rmse:6.45096
# [887]	validation-rmse:6.45099
# [888]	validation-rmse:6.45098
# [889]	validation-rmse:6.45096
# [890]	validation-rmse:6.45098
# [891]	validation-rmse:6.45092
# [892]	validation-rmse:6.45091
# [893]	validation-rmse:6.45092
# [894]	validation-rmse:6.45094
# [895]	validation-rmse:6.45090
# [896]	validation-rmse:6.45084
# [897]	validation-rmse:6.45083
# [898]	validation-rmse:6.45084
# [899]	validation-rmse:6.45084
# [900]	validation-rmse:6.45085
# [901]	validation-rmse:6.45081
# [902]	validation-rmse:6.45081
# [903]	validation-rmse:6.45082
# [904]	validation-rmse:6.45080
# [905]	validation-rmse:6.45077
# [906]	validation-rmse:6.45070
# [907]	validation-rmse:6.45067
# [908]	validation-rmse:6.45067
# [909]	validation-rmse:6.45063
# [910]	validation-rmse:6.45062
# [911]	validation-rmse:6.45059
# [912]	validation-rmse:6.45056
# [913]	validation-rmse:6.45055
# [914]	validation-rmse:6.45052
# [915]	validation-rmse:6.45055
# [916]	validation-rmse:6.45048
# [917]	validation-rmse:6.45040
# [918]	validation-rmse:6.45039
# [919]	validation-rmse:6.45036
# [920]	validation-rmse:6.45032
# [921]	validation-rmse:6.45027
# [922]	validation-rmse:6.45022
# [923]	validation-rmse:6.45022
# [924]	validation-rmse:6.45017
# [925]	validation-rmse:6.45014
# [926]	validation-rmse:6.45011
# [927]	validation-rmse:6.45009
# [928]	validation-rmse:6.45007
# [929]	validation-rmse:6.45003
# [930]	validation-rmse:6.44999
# [931]	validation-rmse:6.44996
# [932]	validation-rmse:6.44995
# [933]	validation-rmse:6.44989
# [934]	validation-rmse:6.44990
# [935]	validation-rmse:6.44988
# [936]	validation-rmse:6.44985
# [937]	validation-rmse:6.44984
# [938]	validation-rmse:6.44985
# [939]	validation-rmse:6.44975
# [940]	validation-rmse:6.44971
# [941]	validation-rmse:6.44976
# [942]	validation-rmse:6.44970
# [943]	validation-rmse:6.44972
# [944]	validation-rmse:6.44970
# [945]	validation-rmse:6.44971
# [946]	validation-rmse:6.44973
# [947]	validation-rmse:6.44974
# [948]	validation-rmse:6.44975
#  26%|██▌       | 13/50 [15:22<43:45, 70.96s/trial, best loss: 6.346631177820434]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 best_result = fmin(
#       2     fn=objective,
#       3     space=search_space,
#       4     algo=tpe.suggest,
#       5     max_evals=50,
#       6     trials=Trials()
#       7 )
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[25], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\xgboost\core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File c:\Users\ASUS\Documents\GitHub\mlops-zoomcamp\.venv\lib\site-packages\xgboost\core.py:2051, in Booster.update(self, dtrain, iteration, fobj)
#    2047 self._assign_dmatrix_features(dtrain)
#    2049 if fobj is None:
#    2050     _check_call(
# -> 2051         _LIB.XGBoosterUpdateOneIter(
#    2052             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2053         )
#    2054     )
#    2055 else:
#    2056     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %% [markdown]
# #### scenario-1

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:///data/mlflow.db'

# %%
client = mlflow.tracking.MlflowClient(tracking_uri = 'sqlite:///data/mlflow.db')
experiment = client.get_experiment_by_name('nyc-taxi-experiment')

runs = client.search_runs(1)
params = runs[0].data.params

# %%
params
# Out:
# {'C': '0.1', 'random_state': '42'}

# %%
from mlflow.exceptions import MlflowException

try:
    client.list_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       1 from mlflow.exceptions import MlflowException
#       3 try:
# ----> 4     client.list_registered_models()
#       5 except MlflowException:
#       6     print("It's not possible to access the model registry :(")
#
# AttributeError: 'MlflowClient' object has no attribute 'list_registered_models'

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# %%
mlflow.set_experiment("nyc-taxi-experiment")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# default artifacts URI: 'file:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/mlruns/1/7fc318707bca4a8b9c539439eac76579/artifacts'

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.tracking import MlflowClient

# Initialize the MlflowClient
client = MlflowClient()

# Print available methods to diagnose the issue
methods = dir(client)
print("Available methods in MlflowClient:")
for method in methods:
    print(method)

# Check if list_registered_models is available
if 'list_registered_models' in methods:
    print("list_registered_models method is available.")
else:
    print("The list_registered_models method is not available in your MlflowClient.")
# Out:
# Available methods in MlflowClient:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# _check_artifact_file_string
# _create_model_version
# _get_registry_client
# _log_artifact_async_helper
# _log_artifact_helper
# _read_from_file
# _record_logged_model
# _registry_uri
# _start_tracked_trace
# _tracking_client
# _upload_ended_trace_info
# _upload_trace_data
# _upload_trace_spans_as_tag
# copy_model_version
# create_experiment
# create_model_version
# create_registered_model
# create_run
# delete_experiment
# delete_model_version
# delete_model_version_tag
# delete_registered_model
# delete_registered_model_alias
# delete_registered_model_tag
# delete_run
# delete_tag
# delete_trace_tag
# delete_traces
# download_artifacts
# end_span
# end_trace
# get_experiment
# get_experiment_by_name
# get_latest_versions
# get_metric_history
# get_model_version
# get_model_version_by_alias
# get_model_version_download_uri
# get_model_version_stages
# get_parent_run
# get_registered_model
# get_run
# get_trace
# list_artifacts
# load_table
# log_artifact
# log_artifacts
# log_batch
# log_dict
# log_figure
# log_image
# log_inputs
# log_metric
# log_param
# log_table
# log_text
# rename_experiment
# rename_registered_model
# restore_experiment
# restore_run
# search_experiments
# search_model_versions
# search_registered_models
# search_runs
# search_traces
# set_experiment_tag
# set_model_version_tag
# set_registered_model_alias
# set_registered_model_tag
# set_tag
# set_terminated
# set_trace_tag
# start_span
# start_trace
# tracking_uri
# transition_model_version_stage
# update_model_version
# update_registered_model
# update_run
# The list_registered_models method is not available in your MlflowClient.

# %%
import mlflow
print(mlflow.__version__)
# Out:
# 2.13.0

# %%
import requests
import json

# Set the tracking URI (ensure this is your tracking server URI)
tracking_uri = "http://127.0.0.1:5000"

# Endpoint for listing registered models
endpoint = f"{tracking_uri}/api/2.0/mlflow/registered-models/list"

# Make the request to the MLflow REST API
response = requests.get(endpoint)
if response.status_code == 200:
    registered_models = response.json().get('registered_models', [])
    for model in registered_models:
        print(json.dumps(model, indent=2))
else:
    print(f"Failed to list registered models: {response.content}")
# Out:
# Failed to list registered models: b'<!doctype html>\n<html lang=en>\n<title>404 Not Found</title>\n<h1>Not Found</h1>\n<p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>\n'

# %% [markdown]
# #### scenario-2

# %%
import mlflow


mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'http://127.0.0.1:5000'

# %%
client = mlflow.tracking.MlflowClient()
experiments = client.list_experiments()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 client = mlflow.tracking.MlflowClient()
# ----> 2 experiments = client.list_experiments()
#
# AttributeError: 'MlflowClient' object has no attribute 'list_experiments'

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2024/05/30 01:16:24 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# default artifacts URI: 'mlflow-artifacts:/2/b6e2bf31dca049888f8af4f4175ad429/artifacts'

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient("http://127.0.0.1:5000")

# %%
client.list_registered_models()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 client.list_registered_models()
#
# AttributeError: 'MlflowClient' object has no attribute 'list_registered_models'

# %%
run_id = client.list_run_infos(experiment_id='1')[0].run_id
mlflow.register_model(
    model_uri=f"runs:/{run_id}/models",
    name='iris-classifier'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 run_id = client.list_run_infos(experiment_id='1')[0].run_id
#       2 mlflow.register_model(
#       3     model_uri=f"runs:/{run_id}/models",
#       4     name='iris-classifier'
#       5 )
#
# AttributeError: 'MlflowClient' object has no attribute 'list_run_infos'

# %%
import mlflow
from mlflow.tracking import MlflowClient

mlflow.set_tracking_uri("sqlite:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/data/mlflow.db")

client = MlflowClient()
experiments = client.list_experiments()

print("List of experiments:")
for experiment in experiments:
    print(f"ID: {experiment.experiment_id}, Name: {experiment.name}")
# Out:
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 7
#       4 mlflow.set_tracking_uri("sqlite:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/data/mlflow.db")
#       6 client = MlflowClient()
# ----> 7 experiments = client.list_experiments()
#       9 print("List of experiments:")
#      10 for experiment in experiments:
#
# AttributeError: 'MlflowClient' object has no attribute 'list_experiments'

# %%
experiment_id = '2'  # Replace with your actual experiment ID

runs = client.search_runs(experiment_ids=[experiment_id])
if not runs:
    print(f"No runs found for experiment ID {experiment_id}")
else:
    for run in runs:
        print(f"Run ID: {run.info.run_id}, Status: {run.info.status}")
# Out:
# Run ID: b6e2bf31dca049888f8af4f4175ad429, Status: FINISHED

# %%
import mlflow
from mlflow import log_metric, log_param, log_artifact

mlflow.set_tracking_uri("sqlite:///c:/Users/ASUS/Documents/GitHub/mlops-zoomcamp/week2/mlruns/mlflow.db")
mlflow.set_experiment("nyc-taxi")

with mlflow.start_run() as run:
    run_id = run.info.run_id
    print(f"Logging a new run with ID: {run_id}")

    # Log parameters, metrics, and artifacts
    log_param("param1", 5)
    log_metric("metric1", 0.85)
    # Save an example artifact
    with open("output.txt", "w") as f:
        f.write("Hello, MLflow!")
    log_artifact("output.txt")

    print(f"Run {run_id} completed.")
# Out:
# 2024/05/30 01:24:22 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi' does not exist. Creating a new experiment.
# Logging a new run with ID: 67adc94bff1e4d9aa633200f0f327ba9
# Run 67adc94bff1e4d9aa633200f0f327ba9 completed.

# %%
from mlflow.tracking import MlflowClient

client = MlflowClient()

# Get the latest run ID for the experiment
experiment_id = '1'
runs = client.search_runs(experiment_ids=[experiment_id])
if not runs:
    print(f"No runs found for experiment ID {experiment_id}")
else:
    # Get the run ID of the latest run
    run_id = runs[0].info.run_id

    # Register the model
    model_uri = f"runs:/{run_id}/models"
    model_name = 'iris-classifier'
    registered_model = mlflow.register_model(model_uri=model_uri, name=model_name)

    print(f"Model registered with name {registered_model.name} and version {registered_model.version}")
# Out:
# Model registered with name iris-classifier and version 1
# Successfully registered model 'iris-classifier'.
# Created version '1' of model 'iris-classifier'.
